# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'serif'
import os

# %%
#reading in all of the data
uvw2_slopes = np.loadtxt('slopes_uvw2.txt', unpack = True)
uvw1_slopes = np.loadtxt('slopes_uvw1.txt', unpack = True)
uvm2_slopes = np.loadtxt('slopes_uvm2.txt', unpack = True)
U_slopes = np.loadtxt('slopes_u.txt', unpack = True)
B_slopes = np.loadtxt('slopes_b.txt', unpack = True)
V_slopes = np.loadtxt('slopes_v.txt', unpack = True)

# %%
#plotting uvw2 histogram
plt.hist(uvw2_slopes, bins = 'rice', color = 'skyblue', edgecolor = 'black')
plt.xlabel('Slope value, mags/day', fontsize = 12)
plt.ylabel('Number of Slopes', fontsize = 12)
plt.title('UVW2 Slope Distribution', fontsize = 12)
plt.savefig(rf"C:\Users\Savannah Stratton\aggienova_stuff\slopes\UVW2_Slopes.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
#plotting uvw1 histogram
plt.hist(uvw1_slopes, bins = 'rice', color = 'skyblue', edgecolor = 'black')
plt.xlabel('Slope value, mags/day', fontsize = 12)
plt.ylabel('Number of Slopes', fontsize = 12)
plt.title('UVW1 Slope Distribution', fontsize = 12)
plt.savefig(rf"C:\Users\Savannah Stratton\aggienova_stuff\slopes\UVW1_Slopes.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
#plotting uvm2 histogram
plt.hist(uvm2_slopes, bins = 'rice', color = 'skyblue', edgecolor = 'black')
plt.xlabel('Slope value, mags/day', fontsize = 12)
plt.ylabel('Number of Slopes', fontsize = 12)
plt.title('UVM2 Slope Distribution', fontsize = 12)
plt.savefig(rf"C:\Users\Savannah Stratton\aggienova_stuff\slopes\UVM2_Slopes.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
#plotting U histogram
plt.hist(U_slopes, bins = 'rice', color = 'skyblue', edgecolor = 'black')
plt.xlabel('Slope value, mags/day', fontsize = 12)
plt.ylabel('Number of Slopes', fontsize = 12)
plt.title('U Slope Distribution', fontsize = 12)
plt.savefig(rf"C:\Users\Savannah Stratton\aggienova_stuff\slopes\U_Slopes.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
#plotting V histogram
plt.hist(V_slopes, bins = 'rice', color = 'skyblue', edgecolor = 'black')
plt.xlabel('Slope value, mags/day', fontsize = 12)
plt.ylabel('Number of Slopes', fontsize = 12)
plt.title('V Slope Distribution', fontsize = 12)
plt.savefig(rf"C:\Users\Savannah Stratton\aggienova_stuff\slopes\V_Slopes.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
#plotting B histogram
plt.hist(B_slopes, bins = 'rice', color = 'skyblue', edgecolor = 'black')
plt.xlabel('Slope value, mags/day', fontsize = 12)
plt.ylabel('Number of Slopes', fontsize = 12)
plt.title('B Slope Distribution', fontsize = 12)
plt.savefig(rf"C:\Users\Savannah Stratton\aggienova_stuff\slopes\B_Slopes.png", dpi=300, bbox_inches="tight")
plt.show()
